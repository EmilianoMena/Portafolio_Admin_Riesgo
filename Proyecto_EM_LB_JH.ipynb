# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://oci02.img.iteso.mx/Identidades-De-Instancia/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" width="400" height="600" />
#
#
# #### <font color='navy'> Proyecto. Administración de Riesgos.
#
# #### <font color='navy'> Cómite de Inversión y Riesgos.
#
#
# Alumnos: *Names*
#
# Profesor: Sean Nicolás González Vázquez.

# %% [markdown]
# ### Objetivos.
#
# > Realizar un proyecto que ayude a un cómite a tomar una decisión de inversión, seleccionando correctamente para un nicho de inversionistas *x* cantidad de activos financieros, además de optimizar y simular el comportamiento del portafolio y posteriormente analizar los riesgos (mercado, operativo y liquidez) del portafolio.
#
# ### Definición el proyecto.
#
# El proyecto constará de las siguientes seis partes, las cuales cuentan con una ponderación específica y serán definidas posteriormente.
#
# |                           | Ponderacion |
# |---------------------------|-------------|
# | 1. Selección de Activos   | 20%         |
# | 2. Obtención de Datos     | 10%         |
# | 3. Optimizacion y Evolución| 10%         |
# | 4. Metricas de Desempeño  | 10%         |
# | 5. Riesgo                 | 30%         |
# | 6. Presentacion           | 20%         |

# %% [markdown]
# ## <font color = "navy"> Parte 1. Selección de Activos <font color = "black">
#
# + Seleccionar de 4 a 6 activos financieros que coticen en bolsa, sientanse libres de utilizar ETF's o acciones.
#
#
# + Justificar la selección de cada uno de los activos con métricas financieras, ya sea con Análisis Técnico o Análisis Fundamental (PER, BPA, EBITDA, Beta). En esta parte se tiene que justificar la selección de la mejor manera posible, incluyendo todo lo que debamos saber acerca del instrumento, es decir, hacer una investigación acerca de las características de las empresas, expectativas, planes a futuro.
#
# Ejemplo: Lo ideal sería seleccionar activos con, por ejemplo PER bajo, pero, si se quiere seleccionar por ejemplo Tesla, comentar todo lo que tiene planeado TESLA para el futuro, además de la perspectiva de mercado para la empresa, lo que causa una sobrevaluación de mercado.
#
# + Comentar acerca de la coyuntura económica.
#
# + Se debe comentar el horizonte de inversión recomendado y el perfil de inversión al que se dirige nuestro portafolio.
#
# **Productos Esperados**: Se muestran los activos elegidos, cada uno con sus respectivas justificaciones y características.
#
# ##  <font color = "navy">  Parte 2. Obtención de Datos <font color = "black">
#
# + Bajar de **FactSet** o de la **API de Yahoo Finance** el precio de cierre ajustado y volumen de los activos seleccionados.
#
#
# + Calcular los rendimientos de tus activos con el cierre de precio ajustado.
#
#
# + Presentar los precios, volumen y rendimientos en un DataFrame. Bajarlos del `01-01-2021` al `12-31-2022`.
#
#
# **Productos Esperados**: Data Frame con los precios, volumen y rendimientos de los activos seleccionados.
#
#
# ##   <font color = "navy">  Parte 3. Optimización de Sharpe y Evolución del Portafolio. <font color = "black">
#
# + Con los rendimientos obtenidos en la parte anterior, obtener las ponderaciones eficientes de sharpe, utilizando como ventana de optimización del `01-01-2021` al `12-31-2021`.
#
#
# + Simular el comportamiento de tu portafolio (rendimientos y evolución del dinero) para el período posterior (`01-01-2022` al `12-31-2022`) y presentarlo en un dataframe. Asumir un capital inicial de $1,000,000 de USD.
#
#
# **Productos Esperados**: Ponderaciones óptimas de Sharpe. Dos Data Frames uno con los rendimientos de tu portafolio y otro con la evolución del valor de tu portafolio. Graficar la evolución del portafolio.
#
#
# ##  <font color = "navy">  Parte 4. Métricas de Desempeño. <font color = "black">
#
# + Armar un data frame que muestre las siguientes métricas de tu portafolio: Rendimiento Esperado, Volatilidad, Ratio de Sharpe y Alpha de Jensen. Se espera que al menos, el Ratio de Sharpe sea positivo.
#
#
# + Comentar acerca de estos, ¿Cuál es la fórmula? ¿Que miden? ¿Que significan los resultados encontrados?.
#
#
# **Productos Esperados**: Data Frame con Métricas de Desempeño y comentar los resultados.
#
#
# ##  <font color = "navy">  Parte 5. Riesgo. <font color = "black">
#
# + Calcular el VaR y el ES a un día con 99% de confianza de tu portafolio. Concluir acerca de este.
#
#
# + Responder en base al volumen promedio de cada activo en los últimos 3 meses, ¿Cuántos días tardarías en deshacer tu posición en cada uno en caso de que vendas todo tu portafolio?
#
#
# + Calcular el VaR en dinero y responder: ¿Si tu límite de VaR es del 10% del valor de tu portafolio (100,000), como administrador de portafolios, ¿Que harías para cumplir el límite de VaR, si lo estas pasando o en el futuro lo pasas? Propon una estrategia específica y clara.
#
#
# + Mostrar la matriz de correlación de los activos de tu portafolio y concluir acerca de los riesgos y/o beneficios que tienes con la diversificación de tu portafolio.
#
#
# + Realizar una investigación acerca de los riesgos individuales más importantes de cada acción. ¿Que pudiera suceder en los siguientes meses que afecte el precio de la acción? ¿Que factores económico-políticos podrían presionar la acción? ¿Tiene algún riesgo específico de operación en el corto plazo?
#
# **Productos Esperados**: VaR, ES, matriz de correlación e investigación.
#
# ##  <font color = "navy">  Parte 6. Presentación. <font color = "black">
#
# Armar en un jupyter notebook una presentación **organizada y concreta por secciones** con todos los puntos, el producto se presenta frente al grupo (*10 a 12 minutos*) y se convence de que es buena idea invertir en el portafolio planteado.

# %% [markdown]
# ## Parte1: selección de activos

# %% [markdown]
# ### Justificacion de selección de activos
#
# -**General Motors**: Tiene un PER que nos hace creer que está infravalorada, tiene un beneficio por acción mayor a cero lo cual es bueno, su Beta se mueve junto con el mercado ya qué es mayor a uno, y tomando en cuenta el auge o reapertura económica esto no es problema, esta empresa tiene planeado tener para 2024 una planta que solo produzca autos electricos a partir de 2024 lo que significa aumento en producción de este tipo de coches e interés del público.
#
# -**OMAB**: su PER es ligeramente alto pero en este caso puede sugerir una expectativa a la alza de los inversionistas, debido al anuncio de una fábrica de TESLA, este aeropuerto problemente aumente su tráfico de carga como comercial, su BPA es bueno, su Beta nos inidica que no se mueve con el mercado, lo cual implica menor riesgo sistematico.
#
# -**NRG**: Viendo el PER se puede asumir que esta infravalorada, tiene un buen beneficio por acción, la Beta nos indica que tiene una relación inversa con el mercado. NRG es la empresa que abastece mas del 60% de la energía de los Estados Unidos a las casas y empresas. Tiene presencia en todo Estados Unidos.
#
# -**Kellog**: Cuenta con un PER alto el cual indica que la empresa puede estar sobrevalorada, el beneficio por acción es positivo, la Beta señala una relación inversa con el mercado. Kellogg es una empresa transnacional con presencia en paises como México, Estados Unidos, España, Colombia, etc.
#
# -**Google**: Tiene un PER que indica que esta un poco sobrevalorada, pero para ser una empresa de tecnología esta bien ese PER, podemos observar un beneficio por accion positivo de 4.75 lo cual es bueno. Además se selecciono esta empresa porque en estos tiempos y en el futruro se esta viendo mucho el aumento de tecnologías, inteligencia artificial y demás.
#
# -**Intel**:Tiene un PER de 13.99 el cual esta dentro de el rango normal, una beta menor a 1 que nos idica que se mueve menos que el mercado, es decir tiene menos riesgo sistemático, su EPS es de 1.94, que si lo comparamos con por ejemplo AMD es más  del doble, tiene un EBITDA de 15.37B, que le gana casi por el triple al de AMD que tiene 4.7B.
#
# Las acciones seleccionadas proveen diversificación al portafolio pues se tiene acciones de sector alimenticio, automotriz, aeropuertario, energetico y tecnológico.

# %%
# Librerías:
import pandas as pd
import numpy as np
import math 
import matplotlib.pyplot as plt

# %%
acciones_df =pd.DataFrame({"Empresa": ["Google", "Intel Corporation", "General Motors Company", "Grupo Aeroportuario","NRG Energy","Kellog"],
        "Ticker": ["GOOGL","INTC", "GM", "OMAB.US","NRG","K"],
        "Beta": [1.09, 0.81, 1.38, 0.89,0.7879,0.2418],
        "EPS/BPA": [4.75, 1.94, 6.13, 10.10,5.17,2.79],
        "PER": [19.79, 13.99, 6.69, 17.84,6.65,23.33],
        "EBITDA(Billions)": [90.77, 15.37, 6.03, 11.45,3.12,2.09]})
acciones_df
# Out:
#                   Empresa   Ticker    Beta  EPS/BPA    PER  EBITDA(Billions)
# 0                  Google    GOOGL  1.0900     4.75  19.79             90.77
# 1       Intel Corporation     INTC  0.8100     1.94  13.99             15.37
# 2  General Motors Company       GM  1.3800     6.13   6.69              6.03
# 3     Grupo Aeroportuario  OMAB.US  0.8900    10.10  17.84             11.45
# 4              NRG Energy      NRG  0.7879     5.17   6.65              3.12
# 5                  Kellog        K  0.2418     2.79  23.33              2.09

# %%
import yfinance as yf
data = yf.download("GOOGL INTC GM OMAB NRG K", start="2021-01-01", end="2022-12-31")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
data=pd.DataFrame(data)
data=data[["Adj Close","Volume"]]

# %%
adjclose=data.iloc[:,0:6]
rends=adjclose.pct_change()
datos=pd.concat([data,rends],axis=1)
datos
# Out:
#             Adj Close                                                         \
#                    GM      GOOGL       INTC          K        NRG       OMAB
# Date
# 2021-01-04  40.234299  86.306503  46.005817  56.757900  33.524063  42.867214
# 2021-01-05  41.376469  87.002502  46.876476  57.081177  33.995060  43.443008
# 2021-01-06  42.687485  86.143997  47.330326  56.637825  34.373711  45.762863
# 2021-01-07  43.025173  88.717003  48.339912  56.240654  34.539944  45.328930
# 2021-01-08  42.766945  89.891502  47.839745  55.603348  36.026817  44.920040
# ...               ...        ...        ...        ...        ...        ...
# 2022-12-23  33.751366  89.230003  25.775923  71.549187  31.550478  64.288368
# 2022-12-27  33.242550  87.389999  25.627729  72.034904  31.876760  63.592777
# 2022-12-28  32.454388  86.019997  25.232544  71.093208  31.501041  63.308662
# 2022-12-29  33.591736  88.449997  25.894478  70.845390  32.034958  62.250576
# ...

# %%
rend_medio=rends.iloc[0:252,:].mean()
rend_medio
# Out:
# Adj Close  GM       0.001767
#            GOOGL    0.002181
#            INTC     0.000445
#            K        0.000407
#            NRG      0.001101
#            OMAB     0.000517
# dtype: float64

# %%
voldiaria=rends.iloc[0:252,:].std()
voldiaria
# Out:
# Adj Close  GM       0.024291
#            GOOGL    0.015312
#            INTC     0.019848
#            K        0.012000
#            NRG      0.023732
#            OMAB     0.019386
# dtype: float64

# %%
año1=pd.DataFrame({"rendimiento anual":252*rend_medio,"Volatilidad esperada":np.sqrt(252)*voldiaria})
año1
# Out:
#                  rendimiento anual  Volatilidad esperada
# Adj Close GM              0.445176              0.385605
#           GOOGL           0.549665              0.243064
#           INTC            0.112147              0.315080
#           K               0.102687              0.190492
#           NRG             0.277406              0.376737
#           OMAB            0.130333              0.307736

# %%
S=np.diag(año1.iloc[:,1])

# %%
corr=rends.iloc[0:252,:].corr()
corr
# Out:
#                 Adj Close
#                        GM     GOOGL      INTC         K       NRG      OMAB
# Adj Close GM     1.000000  0.211426  0.311049 -0.045503  0.026725  0.259296
#           GOOGL  0.211426  1.000000  0.385169 -0.119224  0.165412  0.282638
#           INTC   0.311049  0.385169  1.000000 -0.075019  0.187304  0.274369
#           K     -0.045503 -0.119224 -0.075019  1.000000 -0.049415  0.012743
#           NRG    0.026725  0.165412  0.187304 -0.049415  1.000000  0.135322
#           OMAB   0.259296  0.282638  0.274369  0.012743  0.135322  1.000000

# %%
from scipy.optimize import minimize
# Out:
# C:\Users\Luis\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
## Construcción de parámetros
# 1. Sigma: matriz de varianza-covarianza Sigma = S.dot(corr).dot(S)
S=np.diag(año1.iloc[:,1])
Sigma = S.dot(corr).dot(S).astype(float)
# 2. Eind: rendimientos esperados activos individuales
Eind = año1.iloc[:,0].values.astype(float)

# %%
# Función objetivo
def menos_rs(w, Eind, rf, Sigma):
    ep = Eind.dot(w)
    sp = (w.T.dot(Sigma).dot(w))**0.5
    rs = (ep - rf) / sp
    return -rs

# %%
# Función objetivo
def varianza(w, Sigma):
    return w.T.dot(Sigma).dot(w)

# %%
# Número de activos
n = len(Eind)
# Dato inicial
w0 = np.ones(n) / n
# Cotas de las variables
bnds = ((0, 1),) * n
# Restricciones
cons = {"type": "eq", "fun": lambda w: w.sum() - 1}

# %%
# Portafolio de mínima varianza
minvar = minimize(fun=varianza,
                  x0=w0,
                  args=(Sigma,),
                  bounds=bnds,
                  constraints=cons,
                  tol=1e-10)

# %%
minvar
# Out:
#      fun: 0.016265664547900464
#      jac: array([0.03253442, 0.03253133, 0.03253226, 0.03253052, 0.03253297,
#        0.0325318 ])
#  message: 'Optimization terminated successfully'
#     nfev: 133
#      nit: 19
#     njev: 19
#   status: 0
#  success: True
#        x: array([0.05917089, 0.22687753, 0.05977967, 0.50250008, 0.08454876,
#        0.06712308])

# %%
rf=0.03

# %%
#Rendimiento, volatilidad, ratio de sharpe y pesos para el portafolio de minima varianza
w_minvar = minvar.x
e_minvar = Eind.dot(w_minvar)
s_minvar = (w_minvar.T.dot(Sigma).dot(w_minvar))**0.5
rs_minvar = (e_minvar - rf) / s_minvar
e_minvar, s_minvar, rs_minvar,w_minvar
# Out:
# (0.24155498832085234,
#  0.12753691445185766,
#  1.6587745534702396,
#  array([0.05917089, 0.22687753, 0.05977967, 0.50250008, 0.08454876,
#         0.06712308]))

# %%
# Función objetivo
def menos_rs(w, Eind, rf, Sigma):
    ep = Eind.dot(w)
    sp = (w.T.dot(Sigma).dot(w))**0.5
    rs = (ep - rf) / sp
    return -rs

# %%
# Número de activos
n = len(Eind)
# Dato inicial
w0 = np.ones(n) / n
# Cotas de las variables
bnds = ((0, 1),) * n
# Restricciones
cons = {"type": "eq", "fun": lambda w: w.sum() - 1}

# %%
# Portafolio EMV
emv = minimize(fun=menos_rs,
               x0=w0,
               args=(Eind, rf, Sigma),
               bounds=bnds,
               constraints=cons,
               tol=1e-10)

# %%
emv
# Out:
#      fun: -2.3491848588421704
#      jac: array([-0.18469021, -0.18469837,  1.24900824, -0.18469402, -0.18469501,
#         0.71172276])
#  message: 'Optimization terminated successfully'
#     nfev: 73
#      nit: 10
#     njev: 10
#   status: 0
#  success: True
#        x: array([0.12032408, 0.57463579, 0.        , 0.24305834, 0.06198178,
#        0.        ])

# %%
#Rendimiento, volatilidad y ratio de sharpe para portafolio EMV
w_emv = emv.x
e_emv = Eind.dot(w_emv)
s_emv = (w_emv.T.dot(Sigma).dot(w_emv))**0.5
rs_emv = (e_emv - rf) / s_emv
e_emv, s_emv, rs_emv,w_emv
# Out:
# (0.4115756868895341,
#  0.16242897422623404,
#  2.3491848588421704,
#  array([0.12032408, 0.57463579, 0.        , 0.24305834, 0.06198178,
#         0.        ]))

# %%
num_acc=np.floor(np.array((w_minvar*1000000)/data.iloc[252,0:6]))
posiciones=1000000*w_minvar

# %%
ponderaciones=pd.DataFrame(columns=["GM","GOOG","INTC","K","NRG","OMAB"])
ponderaciones.loc["Ponderaciones"]=[w_minvar[0]*100,w_minvar[1]*100,w_minvar[2]*100,w_minvar[3]*100,w_minvar[4]*100,w_minvar[5]*100]
ponderaciones.loc["Capital asignado"]=np.array(1000000*w_minvar)
ponderaciones.loc["Precio por accion"]=np.array(data.iloc[252,0:6])
ponderaciones.loc["Numero de acciones"]=np.floor(np.array((w_minvar*1000000)/data.iloc[252,0:6]))
ponderaciones.loc["Capital usado"]=np.array(num_acc*data.iloc[252,0:6])
ponderaciones.loc["Capital sobrante"]=np.array(posiciones-num_acc*data.iloc[252,0:6])
ponderaciones
# Out:
#                               GM           GOOG          INTC              K  \
# Ponderaciones           5.917089      22.687753      5.977967      50.250008
# Capital asignado    59170.892248  226877.532036  59779.665776  502500.075959
# Precio por accion      60.753689     144.991501     50.562599      62.003197
# Numero de acciones    973.000000    1564.000000   1182.000000    8104.000000
# Capital usado       59113.339214  226766.707336  59764.992233  502473.906189
# Capital sobrante       57.553034     110.824699     14.673543      26.169770
#
#                              NRG          OMAB
# Ponderaciones           8.454876      6.712308
# Capital asignado    84548.755033  67123.078948
# Precio por accion      40.993820     46.272987
# Numero de acciones   2062.000000   1450.000000
# Capital usado       84529.257233  67095.831680
# Capital sobrante       19.497800     27.247267

# %%
año2=data.iloc[251:,0:6]
rends2=año2.pct_change().fillna(0)
rends2
# Out:
#            Adj Close
#                   GM     GOOGL      INTC         K       NRG      OMAB
# Date
# 2021-12-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2022-01-03  0.043322  0.000963  0.033204  0.004036 -0.002786 -0.006333
# 2022-01-04  0.074710 -0.004083 -0.001316  0.009740 -0.007914 -0.008060
# 2022-01-05 -0.045634 -0.045876  0.013737  0.005512 -0.028156  0.007748
# 2022-01-06  0.002072 -0.000200  0.002599  0.004416 -0.018831  0.007313
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.008947  0.016750  0.004621  0.007116  0.000627  0.045071
# 2022-12-27 -0.015075 -0.020621 -0.005749  0.006789  0.010342 -0.010820
# 2022-12-28 -0.023709 -0.015677 -0.015420 -0.013073 -0.011787 -0.004468
# 2022-12-29  0.035045  0.028249  0.026233 -0.003486  0.016949 -0.016713
# 2022-12-30 -0.000891 -0.002487  0.008394 -0.003218 -0.017901 -0.026755
#
# [252 rows x 6 columns]

# %%
año2.index=pd.to_datetime(año2.index)

# %%
rend_port=pd.DataFrame(columns=["Rendimiento Portafolio 01-01-2022 - 31-12-2022"])
rend_port["Rendimiento Portafolio 01-01-2022 - 31-12-2022"]=np.array((rends2*w_minvar).sum(axis=1))
rend_port.set_index(año2.index,inplace=True)
rend_port
# Out:
#             Rendimiento Portafolio 01-01-2022 - 31-12-2022
# Date
# 2021-12-31                                        0.000000
# 2022-01-03                                        0.006134
# 2022-01-04                                        0.007100
# 2022-01-05                                       -0.011378
# 2022-01-06                                        0.001350
# ...                                                    ...
# 2022-12-23                                        0.011260
# 2022-12-27                                       -0.002355
# 2022-12-28                                       -0.013747
# 2022-12-29                                        0.008611
# 2022-12-30                                       -0.005042
#
# [252 rows x 1 columns]

# %%
evol_port=pd.DataFrame(columns=["Rendimiento porcentual","Evolucion del capital","Perdida/ganancia dia"])
evol_port["Rendimiento porcentual"]=rend_port.iloc[:,0]
rendimientos=rend_port.iloc[:,0]
capital_inicial=(ponderaciones.iloc[4,:]).sum()
capital=[]
for rendimiento in rendimientos:
    capital_actual = capital_inicial * (1 + rendimiento)
    capital.append(capital_actual)
    capital_inicial=capital_actual
evol_port["Evolucion del capital"]=capital
evol_port["Perdida/ganancia dia"]=evol_port.iloc[:,0]*evol_port.iloc[:,1]
#rendimiento sin contar los dolares que sobraron de cada compra de acciones
evol_port
# Out:
#             Rendimiento porcentual  Evolucion del capital  \
# Date
# 2021-12-31                0.000000           9.997440e+05
# 2022-01-03                0.006134           1.005877e+06
# 2022-01-04                0.007100           1.013018e+06
# 2022-01-05               -0.011378           1.001492e+06
# 2022-01-06                0.001350           1.002845e+06
# ...                            ...                    ...
# 2022-12-23                0.011260           9.242062e+05
# 2022-12-27               -0.002355           9.220299e+05
# 2022-12-28               -0.013747           9.093548e+05
# 2022-12-29                0.008611           9.171849e+05
# 2022-12-30               -0.005042           9.125606e+05
#
#             Perdida/ganancia dia
# Date
# 2021-12-31              0.000000
# 2022-01-03           6170.392226
# 2022-01-04           7192.389390
# 2022-01-05         -11394.876708
# 2022-01-06           1354.253867
# ...                          ...
# ...

# %%
evol_port["Evolucion del capital"].plot()
plt.grid()
plt.ylabel('Capital')
plt.legend(loc="upper left", bbox_to_anchor=(1.05, 1))
